# %%
import hyperdata as hd

# %%
hd.plot('temperature_lahore','temperature')
# Out:
# /Users/judah/Code/hyperdata/db.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f'select * from {name}',conn)

# %%
hd.data('temperature_lahore','temperature')
# Out:
# /Users/judah/Code/hyperdata/db.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f'select * from {name}',conn)
#              timestamp  temperature_tokyo  temperature_delhi
# 0     2023-05-07 03:00               22.0               17.6  \
# 1     2023-04-09 09:00               10.9                5.8
# 2     2023-04-09 10:15               14.0                4.4
# 3     2023-04-09 10:30               13.0                4.4
# 4     2023-04-09 11:15               14.0                4.1
# ...                ...                ...                ...
# 1472  2023-05-13 03:30               18.0               27.0
# 1473  2023-05-13 04:15               18.0               26.0
# 1474  2023-05-13 04:30               18.0               26.0
# 1475  2023-05-13 05:00               18.0               26.0
# ...
